# %%
# !pip install streamlit

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,precision_score,f1_score,roc_auc_score,confusion_matrix
# Out:
# C:\Users\mr\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-968a33ee9e26> in <module>
#       4 import matplotlib.pyplot as plt
#       5 from sklearn.model_selection import train_test_split
# ----> 6 from sklearn.tree import DecisionTreeClassifier
#       7 from sklearn.metrics import accuracy_score,precision_score,f1_score,roc_auc_score,confusion_matrix
#
# ~\anaconda3\lib\site-packages\sklearn\tree\__init__.py in <module>
#       4 """
#       5
# ----> 6 from ._classes import BaseDecisionTree
#       7 from ._classes import DecisionTreeClassifier
#       8 from ._classes import DecisionTreeRegressor
#
# ...

# %%
data=pd.read_csv("Heart_disease_Dataset.csv")
data.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0          Yes  14.96     Yes             Yes     No               7
# 1          Yes  36.93     Yes             Yes     No               3
# 2           No  18.70     Yes              No    Yes              26
# 3          Yes  31.43     Yes             Yes    Yes              24
# 4          Yes  75.64      No              No    Yes               2
#
#    MentalHealth DiffWalking     Sex AgeCategory  \
# 0             6         Yes  Female       25-29
# 1            10          No  Female       30-34
# 2            15          No    Male       70-74
# 3            20          No  Female       40-44
# 4            29          No    Male       35-39
#
#                              Race                 Diabetic PhysicalActivity  \
# 0                           White                      Yes              Yes
# 1                        Hispanic  No, borderline diabetes              Yes
# ...

# %%
## check the bottom rows
data.tail()
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 100196           No  48.02      No              No    Yes              13
# 100197          Yes  82.88      No              No     No              29
# 100198           No  39.46      No             Yes    Yes              23
# 100199           No  46.25     Yes             Yes    Yes               9
# 100200           No  39.26     Yes              No     No              10
#
#         MentalHealth DiffWalking     Sex  AgeCategory  \
# 100196            17          No  Female        45-49
# 100197            23          No    Male        75-79
# 100198             6         Yes    Male  80 or older
# 100199            14          No    Male        25-29
# 100200             5         Yes  Female        25-29
#
#                                   Race                 Diabetic  \
# 100196                           White  No, borderline diabetes
# ...

# %%
data.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-3d8483998d6f> in <module>
# ----> 1 data.shape()
#
# TypeError: 'tuple' object is not callable

# %%
data.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
data.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 100196    False
# 100197    False
# 100198    False
# 100199    False
# 100200    False
# Length: 100201, dtype: bool

# %%
len(data[data.duplicated()])
# Out:
# 0

# %%
data.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
#        'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',
#        'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')

# %%
for column in data.columns:
    print(column)
    print(data[column].value_counts())
# Out:
# HeartDisease
# HeartDisease
# Yes    50134
# No     50067
# Name: count, dtype: int64
# BMI
# BMI
# 56.38    26
# 91.47    26
# 27.95    26
# 88.49    26
# 66.39    25
#          ..
# 23.75     3
# 29.15     3
# 65.14     3
# 34.33     2
# 91.36     2
# Name: count, Length: 8284, dtype: int64
# Smoking
# Smoking
# Yes    50445
# No     49756
# Name: count, dtype: int64
# AlcoholDrinking
# AlcoholDrinking
# Yes    50435
# No     49766
# Name: count, dtype: int64
# Stroke
# Stroke
# Yes    50265
# No     49936
# Name: count, dtype: int64
# PhysicalHealth
# PhysicalHealth
# 8     3430
# 20    3401
# 9     3395
# 16    3392
# 19    3386
# 13    3385
# 12    3377
# 26    3369
# 29    3363
# 15    3355
# 23    3354
# 22    3347
# 28    3345
# 14    3343
# 2     3341
# 1     3337
# 10    3334
# 11    3332
# 6     3329
# 0     3328
# 17    3327
# 7     3323
# 24    3316
# 5     3305
# 18    3301
# 3     3287
# 21    3285
# 27    3277
# 25    3270
# 4     3267
# Name: count, dtype: int64
# ...

# %%
data=pd.get_dummies(data,[columns='Sex','AgeCategory','Race','GenHealth'])
# Out:
#   File "<ipython-input-13-db59f42f0589>", line 1
#     data=pd.get_dummies(data,[columns='Sex','AgeCategory','Race','GenHealth'])
#                                      ^
# SyntaxError: invalid syntax

# %%
binary_columns=["Smoking"]

# %%
## applying the get dummies method
data=pd.get_dummies(data,columns=['Sex','AgeCategory','Race','GenHealth'],drop_first=True)
print(data.head())
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0          Yes  14.96     Yes             Yes     No               7
# 1          Yes  36.93     Yes             Yes     No               3
# 2           No  18.70     Yes              No    Yes              26
# 3          Yes  31.43     Yes             Yes    Yes              24
# 4          Yes  75.64      No              No    Yes               2
#
#    MentalHealth DiffWalking                 Diabetic PhysicalActivity  ...  \
# 0             6         Yes                      Yes              Yes  ...
# 1            10          No  No, borderline diabetes              Yes  ...
# 2            15          No                       No               No  ...
# 3            20          No  No, borderline diabetes               No  ...
# 4            29          No                       No              Yes  ...
#
#    AgeCategory_80 or older Race_Asian Race_Black Race_Hispanic  Race_Other  \
# ...

# %%
data.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
x=data.drop(columns=['HeartDisease'])
Y=data['HeartDisease'].map({"Yes":1,"N0":0})

# %%
x.head()
# Out:
#      BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  MentalHealth  \
# 0  14.96     Yes             Yes     No               7             6
# 1  36.93     Yes             Yes     No               3            10
# 2  18.70     Yes              No    Yes              26            15
# 3  31.43     Yes             Yes    Yes              24            20
# 4  75.64      No              No    Yes               2            29
#
#   DiffWalking                 Diabetic PhysicalActivity  SleepTime  ...  \
# 0         Yes                      Yes              Yes       17.1  ...
# 1          No  No, borderline diabetes              Yes        2.7  ...
# 2          No                       No               No       15.6  ...
# 3          No  No, borderline diabetes               No        1.4  ...
# 4          No                       No              Yes        8.8  ...
#
#   AgeCategory_80 or older Race_Asian Race_Black  Race_Hispanic  Race_Other  \
# ...
